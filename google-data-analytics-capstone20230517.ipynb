# %% [markdown]
# # **Case Study: How Does a Bike-Share Navigate Speedy Success?**
#
# **Author: Godspower Micheal**
#
# Date: 05/17/2023
#
# In this case study, i will be following this analysis process
# Ask - Prepare - Process - Analyze - Share - Act
# to complete the Case Study.
#
#
# # **Background**
# # **Scenario**
#
# I am a junior data analyst working in the marketing analyst team at Cyclistic, a bike-share company in Chicago. The director of marketing believes the company’s future success depends on maximizing the number of annual memberships. Therefore, i wants to understand how casual riders and annual members use Cyclistic bikes differently. From these insights, i will design a new marketing strategy to convert casual riders into annual members. But first, Cyclistic executives must approve my recommendations. But first let me get some information about the company.
#
# # **About the company**
#
# In 2016, Cyclistic launched a successful bike-share offering. Since then, the program has grown to a fleet of 5,824 bicycles that are geotracked and locked into a network of 692 stations across Chicago. The bikes can be unlocked from one station and returned to any other station in the system anytime. Until now, Cyclistic’s marketing strategy relied on building general awareness and appealing to broad consumer segments. One approach that helped make these things possible was the flexibility of its pricing plans:
# single-ride passes, full-day passes, and annual memberships. Customers who purchase single-ride or full-day passes are referred to as casual riders. Customers who purchase annual memberships are Cyclistic members. Cyclistic’s finance analysts have concluded that annual members are much more profitable than casual riders. Although the pricing flexibility helps Cyclistic attract more customers, Moreno believes that maximizing the number of annual members will be key to future growth. Rather than creating a marketing campaign that targets all-new customers, Moreno believes there is a very good chance to convert casual riders into members. She notes that casual riders are already aware of the Cyclistic program and have chosen Cyclistic for their mobility needs. Moreno has set a clear goal: Design marketing strategies aimed at converting casual riders into annual members. In order to do that, however, the marketing analyst team needs to better understand how annual members and casual riders differ, why casual riders would buy a membership, and how digital media could affect their marketing tactics. Moreno and her team are interested in analyzing the Cyclistic historical bike trip data to identify trends.
#
#
# # **Case Study Roadmap <- Ask**
#
# > In the Ask process of the Data Analysis, Using guiding questions to identify the business task.
#
# 1.What is the problem you are trying to solve?
# 2.How can your insights drive business decisions?
#
# > The problem am trying to solve is to find the best strategies to increase the annual members by turning all casual biker riders into annual member.*
# > The business insight is to come to a conclusion with the marketing team to increase the annual member.*
#
# **Key tasks**
# 1. Identify the business task
# 2. Consider key stakeholders
#
# > *Analyzing how the Casual biker rider and member biker rider customers use Cyclistic bike share differently.*
#
# Stakeholders are
# Cyclistic executive team,
# Director of Marketing (Lily Moreno),
# Marketing Analytics team.
#
# **Deliverable**
# A clear statement of the business task
#
# *> * Find the actual differences between Casual biker rider and Annual member and compare how digital media to influence casual riders to become members.**
#
# # **Case Study Roadmap <- Prepare**
#
# > In the prepare stage of the Data Analysis I will be using the ROCCC Analysis to prepare the data which stands for Reliable, Original, Comprehensive, Current, and Cited.
# > Download and store the data, Identify how the data is organized,Sort and Filter the data as necessary,Determine the credibility of the data. Using guiding questions
#
# * Where is your data located?
# * How is the data organized?
# * Are there issues with bias or credibility in this data? Does your data ROCCC?
# * How are you addressing licensing, privacy, security, and accessibility?
# * How did you verify the data’s integrity?
# * How does it help you answer your question?
# * Are there any problems with the data?
#
# **Data Source** <- https://divvy-tripdata.s3.amazonaws.com/index.html
#
# **Key tasks**
# 1. Download data and store it appropriately.
# 2. Identify how it’s organized.
# 3. Sort and filter the data.
# 4. Determine the credibility of the data.
#
# **Deliverable**
# A description of all data sources used
#
# > *Source of data provided by the Cylistic company 12 months Between Janunary 2022 and December 2022*

# %% [markdown]
# # **Case Study Roadmap <- Process**
#
# > *In the process stage of the Data Analysis is to make sure the data is clean use the Guiding questions with the tidyverse data package confirm the data structure and the column names *
# > since the we have more dataset i will Concatenate and merge all data into one dataframe
# > by using the package: ‘plyr' and because the data is large i will be using use R for data cleaning and data analysis.*
#
# * What tools are you choosing and why?
# * Have you ensured your data’s integrity?
# * What steps have you taken to ensure that your data is clean?
# * How can you verify that your data is clean and ready to analyze?
# * Have you documented your cleaning process so you can review and share those results?
#
# **Key tasks**
#
# 1. Check the data for errors.
# 2. Choose your tools.
# 3. Transform the data so you can work with it effectively.
# 4. Document the cleaning process
#
# **Deliverable**     Documentation of any cleaning or manipulation of data

# %%
# install and load necessary packages

library(tidyverse)
library(lubridate)
library(janitor)
library(ggplot2)
library(geosphere)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.1.8
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test

# %%
#Collect all data

Jan <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/January.csv")
feb <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/February.csv")
mar <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/March.csv")
apr <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/April.csv")
may <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/May.csv")
jun <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/June.csv")
jul <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/July.csv")
aug <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/August.csv")
sep <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/September.csv")
oct <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/October.csv")
nov <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/November.csv")
dec <- read_csv("/kaggle/input/cyclistic-bikeshare-analysis-case-study/December.csv")
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 247540 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): ride_id, rideable_type, start_station_name, start_station_id, end_...
# dbl  (4): start_lat, start_lng, end_lat, end_lng
# date (2): started_at, ended_at
# time (1): ride_length
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 103770 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): ride_id, rideable_type, start_station_name, start_station_id, end_...
# ...

# %%
#Import all dataset

# check all column name if consistent
colnames(Jan)
colnames(feb)
colnames(mar)
colnames(apr)
colnames(may)
colnames(jun)
colnames(jul)
colnames(aug)
colnames(sep)
colnames(oct)
colnames(nov)
colnames(dec)
# Out:
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "ride_length"        "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "start_lat"          "start_lng"          "end_lat"
# [13] "end_lng"            "member_casual"
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "ride_length"        "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "start_lat"          "start_lng"          "end_lat"
# [13] "end_lng"            "member_casual"
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "ride_length"        "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "start_lat"          "start_lng"          "end_lat"
# [13] "end_lng"            "member_casual"
#  [1] "ride_id"            "rideable_type"      "started_at"
# ...

# %%
# confirm data structure 
str(Jan)
str(feb)
str(mar)
str(apr)
str(may)
str(jun)
str(jul)
str(aug)
str(sep)
str(oct)
str(nov)
str(dec)
# Out:
# spc_tbl_ [247,540 × 14] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:247540] "46F8167220E4431F" "73A77762838B32FD" "4CF42452054F59C5" "3278BA87BF698339" ...
#  $ rideable_type     : chr [1:247540] "electric_bike" "electric_bike" "electric_bike" "classic_bike" ...
#  $ started_at        : Date[1:247540], format: "2021-12-07" "2021-12-11" ...
#  $ ended_at          : Date[1:247540], format: "2021-12-07" "2021-12-11" ...
#  $ ride_length       : 'hms' num [1:247540] 00:07:00 00:27:00 00:13:00 00:14:00 ...
#   ..- attr(*, "units")= chr "secs"
#  $ start_station_name: chr [1:247540] "Laflin St & Cullerton St" "LaSalle Dr & Huron St" "Halsted St & North Branch St" "Halsted St & North Branch St" ...
#  $ start_station_id  : chr [1:247540] "13307" "KP1705001026" "KA1504000117" "KA1504000117" ...
#  $ end_station_name  : chr [1:247540] "Morgan St & Polk St" "Clarendon Ave & Leland Ave" "Broadway & Barry Ave" "LaSalle Dr & Huron St" ...
# ...

# %%
#Concatenating and merge all data into one dataframe.

library(plyr)



tripdata_v1.0 <- bind_rows(Jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec)

colnames(tripdata_v1.0)   #column names 
str(tripdata_v1.0)



#total roll after merge 5667717 of 13 variables
# Out:
# ------------------------------------------------------------------------------
#
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
#
# ------------------------------------------------------------------------------
#
#
# Attaching package: ‘plyr’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following object is masked from ‘package:purrr’:
#
#     compact
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "ride_length"        "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "start_lat"          "start_lng"          "end_lat"
# [13] "end_lng"            "member_casual"
# spc_tbl_ [6,005,142 × 14] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
# ...

# %%
library(dplyr)
library(readr)

nrow(tripdata_v1.0)

dim(tripdata_v1.0)

head(tripdata_v1.0)

tail(tripdata_v1.0)
# Out:
# [1] 6005142
# [1] 6005142      14
#   ride_id          rideable_type started_at ended_at   ride_length
# 1 46F8167220E4431F electric_bike 2021-12-07 2021-12-07 00:07:00
# 2 73A77762838B32FD electric_bike 2021-12-11 2021-12-11 00:27:00
# 3 4CF42452054F59C5 electric_bike 2021-12-15 2021-12-15 00:13:00
# 4 3278BA87BF698339 classic_bike  2021-12-26 2021-12-26 00:14:00
# 5 6FF54232576A3B73 electric_bike 2021-12-30 2021-12-30 00:20:00
# 6 93E8D79490E3AB11 classic_bike  2021-12-01 2021-12-01 00:10:00
#   start_station_name           start_station_id end_station_name
# 1 Laflin St & Cullerton St     13307            Morgan St & Polk St
# 2 LaSalle Dr & Huron St        KP1705001026     Clarendon Ave & Leland Ave
# 3 Halsted St & North Branch St KA1504000117     Broadway & Barry Ave
# 4 Halsted St & North Branch St KA1504000117     LaSalle Dr & Huron St
# 5 Leavitt St & Chicago Ave     18058            Clark St & Drummond Pl
# 6 Wabash Ave & 16th St         SL-012           Wells St & Polk St
# ...

# %%
summary(tripdata_v1.0)
#Statistics summary  but find out there are 4952 NA's  and some duplicate need to clean
# Out:
#    ride_id          rideable_type        started_at
#  Length:6005142     Length:6005142     Min.   :2021-05-01
#  Class :character   Class :character   1st Qu.:2021-06-17
#  Mode  :character   Mode  :character   Median :2021-08-15
#                                        Mean   :2021-08-29
#                                        3rd Qu.:2021-10-15
#                                        Max.   :2022-04-30
#
#     ended_at          ride_length       start_station_name start_station_id
#  Min.   :2021-05-01   Length:6005142    Length:6005142     Length:6005142
#  1st Qu.:2021-06-17   Class1:hms        Class :character   Class :character
#  Median :2021-08-15   Class2:difftime   Mode  :character   Mode  :character
#  Mean   :2021-08-29   Mode  :numeric
#  3rd Qu.:2021-10-15
#  Max.   :2022-05-02
#
#  end_station_name   end_station_id       start_lat       start_lng
#  Length:6005142     Length:6005142     Min.   :41.64   Min.   :-87.84
# ...

# %%
#check for duplicate and clean

tripdata_v1.1 <- tripdata_v1.0[!duplicated(tripdata_v1.0),]
dim(tripdata_v1.1)
summary(tripdata_v1.1)

# %%
# all Na's removed
tripdata_v1.2 <- na.omit(tripdata_v1.1)
summary(tripdata_v1.2)
# Out:
#    ride_id          rideable_type        started_at
#  Length:4399352     Length:4399352     Min.   :2021-05-01
#  Class :character   Class :character   1st Qu.:2021-07-02
#  Mode  :character   Mode  :character   Median :2021-08-21
#                                        Mean   :2021-09-04
#                                        3rd Qu.:2021-10-15
#                                        Max.   :2022-04-30
#     ended_at          ride_length       start_station_name start_station_id
#  Min.   :2021-05-01   Length:4399352    Length:4399352     Length:4399352
#  1st Qu.:2021-07-02   Class1:hms        Class :character   Class :character
#  Median :2021-08-21   Class2:difftime   Mode  :character   Mode  :character
#  Mean   :2021-09-04   Mode  :numeric
#  3rd Qu.:2021-10-15
#  Max.   :2022-05-01
#  end_station_name   end_station_id       start_lat       start_lng
#  Length:4399352     Length:4399352     Min.   :41.65   Min.   :-87.83
# ...

# %%
# finally Confirm the data structure 

str(tripdata_v1.2)
# Out:
# tibble [4,399,352 × 14] (S3: tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:4399352] "46F8167220E4431F" "73A77762838B32FD" "4CF42452054F59C5" "3278BA87BF698339" ...
#  $ rideable_type     : chr [1:4399352] "electric_bike" "electric_bike" "electric_bike" "classic_bike" ...
#  $ started_at        : Date[1:4399352], format: "2021-12-07" "2021-12-11" ...
#  $ ended_at          : Date[1:4399352], format: "2021-12-07" "2021-12-11" ...
#  $ ride_length       : 'hms' num [1:4399352] 00:07:00 00:27:00 00:13:00 00:14:00 ...
#   ..- attr(*, "units")= chr "secs"
#  $ start_station_name: chr [1:4399352] "Laflin St & Cullerton St" "LaSalle Dr & Huron St" "Halsted St & North Branch St" "Halsted St & North Branch St" ...
#  $ start_station_id  : chr [1:4399352] "13307" "KP1705001026" "KA1504000117" "KA1504000117" ...
#  $ end_station_name  : chr [1:4399352] "Morgan St & Polk St" "Clarendon Ave & Leland Ave" "Broadway & Barry Ave" "LaSalle Dr & Huron St" ...
# ...

# %%
#At this point all data cleaning and validation is completed done 
#all duplicates and NAs totally removed. 

view(tripdata_v1.2)

# %% [markdown]
# # **Case Study Roadmap <- Analyze**
#
# > Compare the data between casual biker riders and annual member
#
#
#
# * How should you organize your data to perform analysis on it?
# * Has your data been properly formatted?
# * What surprises did you discover in the data?
# * What trends or relationships did you find in the data?
# * How will these insights help answer your business questions?
#
# **Key tasks**
# 1. Aggregate your data so it’s useful and accessible.
# 2. Organize and format your data.
# 3. Perform calculations.
# 4. Identify trends and relationships.
#
# **Deliverable** A summary of your analysis

# %%
#year_month
#Add year,month and day to column
#day_of_week use to for weekdays 

tripdata_v1.2$date <- as.Date(tripdata_v1.2$started_at)
tripdata_v1.2$month <- format(as.Date(tripdata_v1.2$date), "%m")

tripdata_v1.2 <- tripdata_v1.2 %>%
    mutate(day_of_week = paste(strftime(tripdata_v1.2$ended_at, "%u"), "-", strftime(tripdata_v1.2$ended_at, "%a")))
unique(tripdata_v1.2$day_of_week)

# %%
colnames(tripdata_v1.2)
nrow(tripdata_v1.2) 
dim(tripdata_v1.2)

summary(tripdata_v1.2)
# Out:
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "ride_length"        "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "start_lat"          "start_lng"          "end_lat"
# [13] "end_lng"            "member_casual"      "date"
# [16] "month"              "day_of_week"
# [1] 4399352
# [1] 4399352      17
#    ride_id          rideable_type        started_at
#  Length:4399352     Length:4399352     Min.   :2021-05-01
#  Class :character   Class :character   1st Qu.:2021-07-02
#  Mode  :character   Mode  :character   Median :2021-08-21
#                                        Mean   :2021-09-04
#                                        3rd Qu.:2021-10-15
#                                        Max.   :2022-04-30
#     ended_at          ride_length       start_station_name start_station_id
#  Min.   :2021-05-01   Length:4399352    Length:4399352     Length:4399352
# ...

# %%
head(tripdata_v1.2)

tail(tripdata_v1.2)
# Out:
#   ride_id          rideable_type started_at ended_at   ride_length
# 1 46F8167220E4431F electric_bike 2021-12-07 2021-12-07 00:07:00
# 2 73A77762838B32FD electric_bike 2021-12-11 2021-12-11 00:27:00
# 3 4CF42452054F59C5 electric_bike 2021-12-15 2021-12-15 00:13:00
# 4 3278BA87BF698339 classic_bike  2021-12-26 2021-12-26 00:14:00
# 5 6FF54232576A3B73 electric_bike 2021-12-30 2021-12-30 00:20:00
# 6 93E8D79490E3AB11 classic_bike  2021-12-01 2021-12-01 00:10:00
#   start_station_name           start_station_id end_station_name
# 1 Laflin St & Cullerton St     13307            Morgan St & Polk St
# 2 LaSalle Dr & Huron St        KP1705001026     Clarendon Ave & Leland Ave
# 3 Halsted St & North Branch St KA1504000117     Broadway & Barry Ave
# 4 Halsted St & North Branch St KA1504000117     LaSalle Dr & Huron St
# 5 Leavitt St & Chicago Ave     18058            Clark St & Drummond Pl
# 6 Wabash Ave & 16th St         SL-012           Wells St & Polk St
# ...

# %%
#Concatenating and merge all data into one dataframe.
#columns consistent and combine them into a single worksheet.

library(plyr)



tripdata_v1.2 <- bind_rows(Jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec)

colnames(tripdata_v1.2)   #column names 
str(tripdata_v1.2)



#total roll after merge 5667717 of 13 variables
# Out:
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "ride_length"        "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "start_lat"          "start_lng"          "end_lat"
# [13] "end_lng"            "member_casual"
# spc_tbl_ [6,005,142 × 14] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:6005142] "46F8167220E4431F" "73A77762838B32FD" "4CF42452054F59C5" "3278BA87BF698339" ...
#  $ rideable_type     : chr [1:6005142] "electric_bike" "electric_bike" "electric_bike" "classic_bike" ...
#  $ started_at        : Date[1:6005142], format: "2021-12-07" "2021-12-11" ...
#  $ ended_at          : Date[1:6005142], format: "2021-12-07" "2021-12-11" ...
#  $ ride_length       : 'hms' num [1:6005142] 00:07:00 00:27:00 00:13:00 00:14:00 ...
#   ..- attr(*, "units")= chr "secs"
# ...

# %%
# Data clean and ready for analysis

tripdata_v1.2 <-(tripdata_v1.2 %>%  filter(ride_length>0 ))
nrow(tripdata_v1.2)
# Out:
# [1] 5947000

# %%
#Conduct descriptive analysis

mean(tripdata_v1.2$ride_length)

max(tripdata_v1.2$ride_length)

aggregate(tripdata_v1.2$ride_length ~ tripdata_v1.2$member_casual, FUN = mean)

aggregate(tripdata_v1.2$ride_length ~ tripdata_v1.2$member_casual, FUN = median)

aggregate(tripdata_v1.2$ride_length ~ tripdata_v1.2$member_casual, FUN = max)

aggregate(tripdata_v1.2$ride_length ~ tripdata_v1.2$member_casual, FUN = min)
# Out:
# Time difference of 1234.283 secs
# Time difference of 359100 secs
#   tripdata_v1.2$member_casual tripdata_v1.2$ride_length
# 1 casual                      1752.7596 secs
# 2 member                       808.9068 secs
#   tripdata_v1.2$member_casual tripdata_v1.2$ride_length
# 1 casual                      00:16:00
# 2 member                      00:09:00
#   tripdata_v1.2$member_casual tripdata_v1.2$ride_length
# 1 casual                      359100 secs
# 2 member                       90000 secs
#   tripdata_v1.2$member_casual tripdata_v1.2$ride_length
# 1 casual                      60 secs
# 2 member                      60 secs

# %%
library(tidyverse)

# %%
ggplot(tripdata_v1.2, aes(member_casual, fill=member_casual)) +
    geom_bar() +
    labs(x="Casuals and Members", title="Chart1 - Casuals and Members")

# %% [markdown]
# From the chart this is the overall count, we can see members have more quantity than casuals
# the gap between both is over 20% more.

# %%
ggplot(data = tripdata_v1.2) +
  geom_bar(mapping = aes(x = member_casual,fill=rideable_type ))+
  labs(title = "Chart2 Type of bikes taken") + coord_flip()

# %% [markdown]
# member use more of classic bike and for electic bike is used more my casual riders

# %%
tripdata_v1.2 %>%
  ggplot(aes(day_of_week, fill=member_casual)) +
    geom_bar() +
    labs(x="day_of_week", title="Chart3 - Total riders by day of week")

# %% [markdown]
# From the chart there more casual riders in the weekends compare to members

# %%
tripdata_v1.2 %>%
  ggplot(aes(month, fill=member_casual)) +
    geom_bar() +
    labs(x="Month", title="Chart4 - Total riders by month") +
    coord_flip()

# %% [markdown]
# In chart4 biggest count of data points was May with ~25% increase of riders.
# all the months we have more members riders than casual riders
# The difference between member and casual is in Q2 & Q3 2021 the gap is small compare to other months.

# %% [markdown]
# # Case Study Roadmap <- Share
#
# On kaggle the presentation will be on Notebook
#
# > From the analysis we can see annual members riders are more active on weekday,while casual riders are relative active more on the weekend (saturdays and sundays).
# > also casual riders travel at the same average distance than the member users.
# > In conclusion the membership riders use the service for their daily commuting while casual rider use the service mosly weekend and for fun and they are more likely to return their bikes at the same pick station.
#
# **Key tasks**
#
# 1. Determine the best way to share your findings.
# 2. Create effective data visualizations.
# 3. Present your findings.
# 4. Ensure your work is accessible.
#
# **Deliverable**  Supporting visualizations and key findings

# %% [markdown]
# # Case Study Roadmap <- Act
#
# > Casual riders use more bikes on weekends than members.
# > On average there are more casual riders than member riders and which is about twice on weekends.
# > Members have taken more rides than casuals,and use more of classic bike and for electic bike is used more my casual riders.
# >
# > in order to increase the riders to get membership since casual riders ride more on weekends, there should be benefits offered to casual rider on weekends which should attract casual riders to become members since there is more casual rider in the weekends this should be the target to get more membership.
# >
# > Casual riders should be enlightened on the benefits of becoming members.
# >
# **Key tasks**
#
# 1. Create your portfolio.
# 2. Add your case study.
# 3. Practice presenting your case study to a friend or family member.
#
# **Deliverable** Your top three recommendations based on your analysis
